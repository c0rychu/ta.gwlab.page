# %% [markdown]
# ## EM

# %%
from astropy import units as u, constants as c
import numpy as np

# %%
(u.u).to(u.kg)
# Out:
# 1.66053906892e-27

# %%
c.e
# Out:
# <<class 'astropy.constants.codata2022.EMCODATA2022'> name='Electron charge' value=1.602176634e-19 uncertainty=0.0 unit='C' reference='CODATA 2022'>

# %% [markdown]
# $k_e = \frac{1}{4 \pi \epsilon_0}$

# %%
ke = (1 / (4 * np.pi * c.eps0)).to(u.N * u.m**2 / u.C**2)
ke
# Out:
# <Quantity 8.98755179e+09 m2 N / C2>
